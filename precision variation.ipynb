# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x  = [10., 100., 1000., 5000., 10000. ]
y1 = [37867.3320579, 4278.16474861, 773.479848773, 455.598595888, 683.037970814]
y2 = [11575.8104143, 1093.45730932, 204.116657969, 160.13158888, 212.489148517]
plt.figure(figsize=(20,15))
plt.plot(x, y2, marker='x',linestyle=' ',  color='black', markersize=20 )

plt.plot([5, 20000], [0.0012*100000, 0.0012*100000], 'k-', linestyle='-.', lw=2)
plt.text(10, 110, "MCNP st-dev", ha="center", va="center", size=20)
plt.ylim([50,20000])
plt.xlim([5,20000])
plt.xticks( fontsize = 24)

plt.yticks( fontsize = 24)

plt.xscale('log')
plt.yscale('log')
plt.grid(which = 'minor')
plt.xlabel('Number of Training Samples', fontsize=24)
plt.ylabel(r'$<\sigma _{Kinf} >$ [pcm]', fontsize=24)

plt.savefig('prevision.png')

# %%
15792.5923517/100000
# Out:
# 0.157925923517
